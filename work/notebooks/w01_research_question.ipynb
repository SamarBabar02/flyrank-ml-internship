# %% [markdown]
# <a href="https://colab.research.google.com/github/SamarBabar02/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/SamarBabar02/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# **Refresh / Content Opportunity Scoring**
#
# I chose the Refresh / Content Opportunity Scoring lane because I am interested in using Machine Learning to help identify which web pages should be reviewed first for content updates. Instead of relying only on manual decisions, I want to explore how search performance, engagement, and content-related signals can be used to prioritize pages that are more likely to benefit from a review. This lane matches my interest in practical Machine Learning and decision-support systems, and I believe it will allow me to build a useful and explainable solution over the next seven weeks.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ### Decision
# Determine which web pages should be reviewed first and recommend the most appropriate type of content action (such as refresh, expand, improve CTR, or monitor).
#
# ### Who takes the action?
# SEO specialists or content managers.
#
# ### Cost of a wrong recommendation
# An incorrect recommendation may waste time and resources by updating pages that do not need attention while missing pages that have a real opportunity to improve. This can reduce the effectiveness of content optimization efforts.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# !git clone https://github.com/SamarBabar02/flyrank-ml-internship.git
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (87/87), done.
# remote: Total 123 (delta 38), reused 88 (delta 20), pack-reused 0 (from 0)
# Receiving objects: 100% (123/123), 1.84 MiB | 14.59 MiB/s, done.
# Resolving deltas: 100% (38/38), done.

# %%
# %cd flyrank-ml-internship
# Out:
# /content/flyrank-ml-internship/flyrank-ml-internship

# %% [markdown]
# import pandas as pd
#
# df = pd.read_csv("/content/flyrank-ml-internship/data/raw/content_refresh_anonymized.csv")
#
# # Dataset size
# print("Total pages:", len(df))
#
# # Average CTR
# print("Average CTR:", round(df["ctr"].mean(), 4))
#
# # Pages with high impressions but low CTR
# opportunity_pages = df[
#     (df["impressions_90d"] > df["impressions_90d"].median()) &
#     (df["ctr"] < df["ctr"].median())
# ]
#
# print("High impression + low CTR pages:", len(opportunity_pages))

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ### What my work can claim
#
# This project can identify web pages that may be good candidates for review by analyzing observed search performance, engagement, and content-related signals. The recommendations will be decision-support only and will help prioritize which pages should be reviewed first and what type of action may be appropriate (such as refresh, improve CTR, expand content, or monitor).
#
# ### What my work cannot claim
#
# This project cannot prove that updating a page will definitely improve its Google ranking or traffic. It also cannot predict Google's algorithm or guarantee that a specific content update will produce a certain ranking improvement. Final decisions should always be reviewed by a human.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
